# %% [markdown]
# <a href="https://colab.research.google.com/github/LicaCepillo/LicaCepillo/blob/main/Probabilidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROBABILIDADE**

# %%
import numpy as np
import pandas as pd

# %%
enem_sp = pd.read_csv('/content/drive/MyDrive/Python_projetos_reforço/enem_2019_tratado.csv',sep=',', encoding='iso-8859-1')

# %%
enem_guarulhos = enem_sp.loc[enem_sp.MUNICIPIO == 'Guarulhos']

# %%
enem_bauru = enem_sp.loc[enem_sp.MUNICIPIO == 'Bauru']

# %%
enem_guarulhos.head()
# Out:
#     INSCRICAO  MUNICIPIO  IDADE SEXO ESTADO_CIVIL           RACA  \
# 4    1,90E+11  Guarulhos     23    F     solteiro         branca
# 56   1,90E+11  Guarulhos     17    F     solteiro          parda
# 69   1,90E+11  Guarulhos     27    M     solteiro  não_declarado
# 130  1,90E+11  Guarulhos     28    F     solteiro         branca
# 202  1,90E+11  Guarulhos     17    F     solteiro          parda
#
#      NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 4    brasileiro(a)                1  não_respondeu         NaN  ...   796.1
# 56   brasileiro(a)                2        pública         NaN  ...   468.1
# 69   brasileiro(a)                1  não_respondeu         NaN  ...   743.8
# 130  brasileiro(a)                1  não_respondeu         NaN  ...   415.1
# 202  brasileiro(a)                2        pública  35005824.0  ...   594.9
#
#      TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# 4       Inglês                1.0  160.0  200.0  180.0  180.0  160.0
# 56    Espanhol                1.0  100.0   60.0   60.0  100.0    0.0
# 69      Inglês                1.0  120.0  180.0  120.0  120.0  160.0
# 130     Inglês                1.0  160.0  120.0  160.0  120.0  100.0
# 202     Inglês                1.0  120.0  120.0  120.0  120.0  160.0
#
#      NOTA_REDACAO INTERNET
# 4           880.0      Sim
# 56          320.0      Sim
# 69          700.0      Sim
# 130         660.0      Sim
# 202         640.0      Sim
#
# [5 rows x 28 columns]

# %%
enem_bauru.head()
# Out:
#      INSCRICAO MUNICIPIO  IDADE SEXO ESTADO_CIVIL     RACA  NACIONALIDADE  \
# 477   1,90E+11     Bauru     21    M     solteiro   branca  brasileiro(a)
# 928   1,90E+11     Bauru     17    M     solteiro  amarela  brasileiro(a)
# 1070  1,90E+11     Bauru     19    M     solteiro   branca  brasileiro(a)
# 1235  1,90E+11     Bauru     18    F     solteiro    parda  brasileiro(a)
# 1506  1,90E+11     Bauru     19    M     solteiro   branca  brasileiro(a)
#
#       TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  TP_LINGUA  \
# 477                 1  não_respondeu         NaN  ...   664.1     Inglês
# 928                 2        pública  35025240.0  ...   740.3     Inglês
# 1070                1  não_respondeu         NaN  ...   789.2     Inglês
# 1235                2        privada  35115435.0  ...    71.5     Inglês
# 1506                1  não_respondeu         NaN  ...   533.8   Espanhol
#
#       TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  NOTA_REDACAO  \
# 477                 1.0  100.0  120.0  120.0  120.0  100.0         560.0
# 928                 1.0  140.0  120.0  120.0  140.0  100.0         620.0
# 1070                1.0  160.0  200.0  200.0  200.0  200.0         960.0
# 1235                1.0  140.0  140.0  140.0  140.0  120.0         680.0
# 1506                1.0  120.0  140.0  120.0  100.0  140.0         620.0
#
#      INTERNET
# 477       Sim
# 928       Sim
# 1070      Sim
# 1235      Sim
# 1506      Sim
#
# [5 rows x 28 columns]

# %%
len(enem_guarulhos)
# Out:
# 15647

# %%
len(enem_bauru)
# Out:
# 4171

# %%
enem_guarulhos.shape
# Out:
# (15647, 28)

# %%
enem_bauru.shape
# Out:
# (4171, 28)

# %%
len(enem_sp)
# Out:
# 499940

# %%
# CRIAÇÃO DE FUNÇÃO DE  PROBALIDADE 
# Elementos do A é o número de elementos do grupo A e o B é o número de elementos da amostra.


def probab (A,E):
  resultado = (A/E)*100
  print('{:.2f}'.format(resultado))

# %%
# PROBABILIDADE DE RETIRAR UM VESTIBULANDO DE GUARULHOS

probab (len(enem_guarulhos), len(enem_sp))
# Out:
# 3.13

# %%
# PROBABILIDADE DE RETIRAR UM VESTIBULANDO DE BAURU

probab (len(enem_bauru),len(enem_sp))
# Out:
# 0.83

# %% [markdown]
# #Probabilidade de não ocorrer um evento

# %%
# CRIANDO FUNÇÃO PROBALIDADE DE NÃO OCORRER UM EVENTO

def probab_nao (A,E):
  resultado = (1- (A/E))*100
  print('{:.2f}'.format(resultado))

# %%
# ROBABILIDADE DE NÃO RETIRAR UM VESTIBULANDO DE GUARULHOS
probab_nao (len(enem_guarulhos),len(enem_sp))
# Out:
# 96.87

# %%
# PROBABILIDADE DE NÃO RETIRAR UM VESTIBULANDO DE BAURU
probab_nao (len(enem_bauru),len(enem_sp))
# Out:
# 99.17

# %%
# PROBABILIDADE DE NÃO RETIRAR UM VESTIBULANDO DE GUARULHOS E NEM DE BAURU
probab_nao (len(enem_guarulhos) + len(enem_bauru),len(enem_sp))
# Out:
# 96.04

# %% [markdown]
# #**Probabilidade de União de Eventos**

# %% [markdown]
# ##Probabilidade da união mutuamente exclusivos (AUB)

# %%
# CRIANDO FUNÇÃO PROBABILIDADE DA UNIÃO MUTUAMENTE EXCLUSIVOS (AUB) - Evento A, Evento B e E espeço amostral

def probab_uniao (A,B,E):
  resultado = (A/E + B/E)*100
  print('{:.3}'.format(resultado))

# %%
# PROBABILIDADE DE RETIRAR UM VESTIBULANDO DE GUARULHOS OU DE BAURU

probab_uniao(len(enem_guarulhos),len(enem_bauru), len(enem_sp))
# Out:
# 3.96

# %% [markdown]
# #Probabilidade da Intercecção de dois eventos
# ###Dois eventos independentes

# %%
# CRIANDO FUNÇÃO PROBABILIDADE DA INTERSECÇÃO DE DOIS EVENTOS

def probab_inter(A, B, E):
  resultado = (A/E * B/E)*100
  print('{:.3f}'.format(resultado))

# %%
# PROBABILIDADE DE RETIRAR UM VESTIBULANDO DE GUARULHOS E DE BAURU (com reposição)

probab_inter(len(enem_guarulhos),len(enem_bauru), len(enem_sp))
# Out:
# 0.026

# %% [markdown]
# #Probabilidade Condicional
# ### Probabilidade de ocorrência do evento A **condicionada** ao evento B

# %%
# CRIANDO FUNÇÃO PROBABILIDADE CONDICIONAL

def probab_cond (AB, B):
  resultado = (AB /B)*100
  print('{:.2f}'.format(resultado))

# %%
# PROBAGILIDADE DE RETIRAR UMA MULHER PARDA

mulher = enem_sp.loc[enem_sp.SEXO == 'F']

# %%
mulher_parda = mulher.loc[mulher.RACA == 'parda']

# %%
mulher_parda.head(20)
# Out:
#    INSCRICAO         MUNICIPIO  IDADE SEXO                 ESTADO_CIVIL  \
# 1   1,90E+11         São Paulo     17    F                     solteiro
# 3   1,90E+11        Embu-Guaçu     17    F                     solteiro
# 7   1,90E+11       Santo André     20    F                     solteiro
# 9   1,90E+11       Santo André     44    F  Casado/Mora com companheiro
# 11  1,90E+11             Guará     17    F                     solteiro
# 13  1,90E+11            Osasco     17    F                     solteiro
# 16  1,90E+11         São Paulo     18    F                     solteiro
# 19  1,90E+11            Santos     29    F                     solteiro
# 25  1,90E+11          Bertioga     26    F                     solteiro
# 29  1,90E+11    Novo Horizonte     19    F                     solteiro
# 31  1,90E+11          Campinas     19    F                     solteiro
# 32  1,90E+11             Cotia     19    F                     solteiro
# 34  1,90E+11  Águas de Lindóia     21    F                     solteiro
# 41  1,90E+11           Barueri     21    F                     solteiro
# 44  1,90E+11  Águas de Lindóia     17    F                     solteiro
# 46  1,90E+11         Igarapava     19    F                     solteiro
# 47  1,90E+11         Mairinque     31    F                     solteiro
# 56  1,90E+11         Guarulhos     17    F                     solteiro
# 74  1,90E+11           Socorro     23    F                     solteiro
# 75  1,90E+11       Santo André     24    F                     solteiro
#
#      RACA  NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ...  \
# 1   parda  brasileiro(a)                2        privada  15567761.0  ...
# 3   parda  brasileiro(a)                2        pública         NaN  ...
# 7   parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 9   parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 11  parda  brasileiro(a)                2        pública  35023310.0  ...
# 13  parda  brasileiro(a)                2        pública  35040770.0  ...
# 16  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 19  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 25  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 29  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 31  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 32  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 34  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 41  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 44  parda  brasileiro(a)                2        pública  35017632.0  ...
# 46  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 47  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 56  parda  brasileiro(a)                2        pública         NaN  ...
# 74  parda  brasileiro(a)                1  não_respondeu         NaN  ...
# 75  parda  brasileiro(a)                1  não_respondeu         NaN  ...
#
#    NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# 1    731.8     Inglês                1.0  160.0  120.0  200.0  200.0  200.0
# 3    419.2     Inglês                1.0  120.0  120.0  120.0  120.0   80.0
# 7    508.5   Espanhol                1.0  120.0  120.0  120.0  100.0   80.0
# 9    488.1   Espanhol                1.0  120.0  120.0  120.0  120.0   40.0
# 11   535.1     Inglês                1.0  140.0  120.0  140.0  160.0  120.0
# 13   423.8   Espanhol                1.0  140.0  120.0  120.0  140.0    0.0
# 16   612.9     Inglês                1.0  160.0  200.0  160.0  180.0  180.0
# 19   544.9   Espanhol                1.0  120.0  120.0  100.0  100.0   80.0
# 25   649.8     Inglês                1.0  160.0  200.0  160.0  200.0  140.0
# 29   448.1     Inglês                1.0  100.0  120.0  100.0  120.0   80.0
# 31    73.1     Inglês                1.0  140.0  120.0  160.0  140.0  160.0
# 32   432.9   Espanhol                1.0  100.0  120.0  120.0  100.0  140.0
# 34   363.1   Espanhol                1.0  120.0  120.0  120.0  120.0    0.0
# 41   458.8   Espanhol                1.0  160.0  120.0  160.0  160.0  180.0
# 44   451.9     Inglês                1.0  140.0  120.0  140.0  160.0  160.0
# 46   478.1   Espanhol                1.0  120.0  160.0  120.0  140.0  100.0
# 47   695.9   Espanhol                1.0  140.0  200.0  180.0  200.0  200.0
# 56   468.1   Espanhol                1.0  100.0   60.0   60.0  100.0    0.0
# 74   469.2   Espanhol                1.0  160.0  200.0  180.0  160.0   80.0
# 75   703.7   Espanhol                1.0  100.0  120.0  120.0  120.0  120.0
#
#     NOTA_REDACAO INTERNET
# 1          880.0      Não
# 3          560.0      Sim
# 7          540.0      Sim
# 9          520.0      Sim
# 11         680.0      Sim
# 13         520.0      Não
# 16         880.0      Sim
# 19         520.0      Sim
# 25         860.0      Sim
# 29         520.0      Sim
# 31         720.0      Sim
# 32         580.0      Não
# 34         480.0      Sim
# 41         780.0      Sim
# 44         720.0      Não
# 46         640.0      Sim
# 47         920.0      Sim
# 56         320.0      Sim
# 74         780.0      Não
# 75         580.0      Sim
#
# [20 rows x 28 columns]

# %%
probab_cond(len(mulher_parda),len(mulher))
# Out:
# 30.76
